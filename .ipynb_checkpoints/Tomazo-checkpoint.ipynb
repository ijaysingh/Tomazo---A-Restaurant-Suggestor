# %%
import requests

# %%
def cityData(cityName):
    
    #extracting the data of entered city
    req = requests.get("https://developers.zomato.com/api/v2.1/cities",
                        params={'user-key': '627c28c07ad221c65491bbffea6f5d54', 'q': cityName},
                        headers={'Accept': 'application/json', 'user-key': '627c28c07ad221c65491bbffea6f5d54'})
    result1 = req.json()
    
    
    #extracting id of the requested city for further processing
    for item in result1['location_suggestions']:
        if item["country_name"] == "India":
            cityID = item["id"]

    #extracting cuisine data using cityID
    req = requests.get("https://developers.zomato.com/api/v2.1/cuisines", 
                       params={'user-key': '627c28c07ad221c65491bbffea6f5d54', "city_id": cityID}, 
                       headers={'Accept': 'application/json', 'user-key': '627c28c07ad221c65491bbffea6f5d54'})
    result2 = req.json()
    
    #extracting cuisineID of every cuisine vailable for the city
    cityCuisineName = {}
    for item in result2["cuisines"]:
        cityCuisineName[item['cuisine']['cuisine_name']] = item['cuisine']['cuisine_id']
    
    #creating a list that contain list of cuisines in alphabetical order
    lstDish = []
    i = 0
    for key in sorted(cityCuisineName):
        lstDish.append(key)
    
    dish = input("\nEnter Your Desired Cuisine: ")
    dish = dish.capitalize()
    print()
    
    #Extracting data of the entered city
    req = requests.get('https://developers.zomato.com/api/v2.1/locations',
                   params = {'user-key' : '627c28c07ad221c65491bbffea6f5d54', 'query' : cityName},
                   headers = {'Accept' : 'application/json', 'user-key' : '627c28c07ad221c65491bbffea6f5d54'})
    result3 = req.json()
    
    # Extracting entityId (uniqueId of every city) of city
    for item in result3['location_suggestions']:
        entityType = item['entity_type']
        entityID = item['entity_id']
        
    # Extracting top 10 restaurant for desired cuisine using the entity id in sorted order based on its rating   
    for item in result3['location_suggestions']:
        entityType = item['entity_type']
        entityID = item['entity_id']
        req = requests.get("https://developers.zomato.com/api/v2.1/search", 
                           params = {'user-key' : '627c28c07ad221c65491bbffea6f5d54', 
                                     'entity_id': entityID, 'entity_type': entityType, 
                                     'count' : 10, 'cuisines' : cityCuisineName[dish], 'sort' : 'rating', 'order' : 'dsc'},
                      headers = {'Accept' : 'application/json', 'user-key' : '627c28c07ad221c65491bbffea6f5d54'})
        result4 = req.json()
    
    # Printing data in a formatted way
    if dish in lstDish:
        for i in result4['restaurants']:
            print("Name:", i['restaurant']['name'])
            print("Rating:", i['restaurant']['user_rating']['aggregate_rating'])
            print("Address:", i['restaurant']['location']['address'])
            print("Dishes:", i['restaurant']['cuisines'])
            print("Timing:", i['restaurant']['timings'])
            if i['restaurant']['has_online_delivery'] == 1:
                print("Has Onine Delivery: Yes")
            else:
                print("Has Onine Delivery: No")
            if i['restaurant']['is_delivering_now'] == 0:
                print("Is Delivering Now: No")
            else:
                print("Is Delivering Now: Yes")
            print("Mob No.:", i['restaurant']['phone_numbers'])
            print("\n---------------------------------------------\n")
    else:
        print("cuisine is not available")

# %%
cityData('Lucknow')
# Out:
# Enter Your Desired Cuisine: biryani
#
# Name: Dastarkhwan
# Rating: 4.5
# Address: 20, DM Compound Colony, Near Kaiserbagh Officers Colony, Wala Qadar Road, Kaiserbagh, Lucknow
# Dishes: Mughlai, North Indian, Kebab, Biryani
# Timing: 1pm – 10:30pm (Mon-Sun)
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: 0522 4307866, +91 7860736766
#
# ---------------------------------------------
#
# Name: Lalla Biryani
# Rating: 4.5
# Address: Chaupatia Chauraha, Chowk, Lucknow
# Dishes: Biryani, North Indian
# Timing: 4pm – 8pm (Mon, Wed, Thu, Fri, Sat, Sun), Closed (Tue)
# Has Onine Delivery: Yes
# Is Delivering Now: No
# Mob No.: +91 9889194949
#
# ---------------------------------------------
#
# Name: Fusion Flavour
# Rating: 4.4
# Address: Plot 10, Sector 9, Vikas Nagar, Aliganj, Lucknow
# Dishes: North Indian, Biryani, Mughlai, Chinese
# Timing: 11 AM to 11 PM
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 6390340026
#
# ---------------------------------------------
#
# Name: Biryani By Kilo
# Rating: 4.4
# Address: B-3/1, Type-B, Floor 1, Vibhuti Khand, Gomti Nagar, Lucknow
# Dishes: Biryani, Mughlai, Kebab, Hyderabadi
# Timing: 10am – 11pm (Mon-Sun)
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 9555212212
#
# ---------------------------------------------
#
# Name: Kareem Kababi
# Rating: 4.3
# Address: Masjid Khawas, Maulviganj, Aminabad, Lucknow
# Dishes: Kebab, Lucknowi, Rolls, Burger, Biryani
# Timing: 12:30 PM to 11 PM (Mon-Thu, Sat-Sun), 1 PM to 11 PM (Fri)
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 6307670970, +91 7570074301
#
# ---------------------------------------------
#
# Name: Acacia - Biriyani, Kebabs & Wraps
# Rating: 4.3
# Address: 1/117, Lohia Park Road, Vijay Khand, Gomti Nagar, Lucknow
# Dishes: Wraps, North Indian, Biryani, Mughlai
# Timing: 11 AM to 11:30 PM
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 8896507997
#
# ---------------------------------------------
#
# Name: Madhurima Sweets
# Rating: 4.3
# Address: Vibhuti Khand, Near Comfort Inn, Gomti Nagar, Lucknow
# Dishes: Chinese, North Indian, South Indian, Biryani, Desserts, Beverages
# Timing: 8 AM to 10:30 PM (Mon-Sun)
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: 0522 22721672
#
# ---------------------------------------------
#
# Name: Mughlai Roll Corner
# Rating: 4.3
# Address: 17/3, Ashok Marg, Hazratganj, Lucknow
# Dishes: Biryani, Rolls, Street Food
# Timing: 11 AM to 10:30 PM
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 9807070777
#
# ---------------------------------------------
#
# Name: Biryani Corner
# Rating: 4.4
# Address: 450/522, Abbas Nagar, Muftiganj Husainabad Thakurganj, Chowk, Lucknow
# Dishes: Biryani
# Timing: 12 Midnight to 2 AM, 7 AM to 12 Midnight
# Has Onine Delivery: Yes
# Is Delivering Now: No
# Mob No.: +91 7786984404
#
# ---------------------------------------------
#
# Name: Non Veg Ghar
# Rating: 4.3
# Address: Shop 3, Umama Market, Pani Gaon, Indira Nagar, Lucknow
# Dishes: North Indian, Lucknowi, Biryani, Desserts
# Timing: 5 PM to 11 PM (Mon-Sun)
# Has Onine Delivery: Yes
# Is Delivering Now: Yes
# Mob No.: +91 8127610487, +91 9936349172, +91 9305742799
#
# ---------------------------------------------
